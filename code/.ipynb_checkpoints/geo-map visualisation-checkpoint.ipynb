# %%
import pandas as pd
import warnings
import numpy as np
warnings.filterwarnings("ignore")

import folium
from folium.plugins import FastMarkerCluster
from folium.plugins import HeatMap
from bokeh.plotting import figure, show
from bokeh.tile_providers import get_provider, Vendors
from bokeh.io import save, reset_output, output_notebook
reset_output()
output_notebook()
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab

import geopandas as gpd
import seaborn as sns

from numpy import log, sqrt
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
tips_sample=pd.read_feather('../preprocessed_data/sample.feather')
# this sample is generated in "visualisations with weather data set.ipynb", and I read it here directly.

# %%
tips_sample
# Out:
#         tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0        2018-03-14 22:52:13   2018-03-14 22:55:20                2
# 1        2018-02-06 09:53:25   2018-02-06 10:05:49                1
# 2        2018-02-22 13:05:15   2018-02-22 13:12:47                1
# 3        2018-02-08 09:22:02   2018-02-08 09:43:31                4
# 4        2018-03-21 08:30:30   2018-03-21 08:44:51                1
# ...                      ...                   ...              ...
# 7096482  2018-08-25 10:10:14   2018-08-25 10:23:03                1
# 7096483  2018-07-12 21:55:11   2018-07-12 22:26:03                1
# 7096484  2018-08-10 05:22:13   2018-08-10 05:28:46                2
# 7096485  2018-07-07 23:50:53   2018-07-07 23:56:27                1
# 7096486  2018-09-21 18:16:14   2018-09-21 18:41:44                1
#
#          trip_distance  PULocationID  DOLocationID  payment_type  fare_amount  \
# 0                 0.70           164           170             2          4.5
# 1                 1.97           239           236             1         10.0
# 2                 1.10           237           262             1          7.0
# 3                 5.54           170           261             1         21.0
# 4                 6.00           137           168             1         18.0
# ...                ...           ...           ...           ...          ...
# 7096482           2.23           168           263             1         10.5
# 7096483           7.60           114            74             1         27.0
# 7096484           1.10           100           164             2          6.5
# 7096485           1.20           162           107             1          6.5
# 7096486           3.20           263           137             1         17.5
#
#          extra  mta_tax  ...  tolls_amount  total_amount       date holiday  \
# 0          0.5      0.5  ...           0.0          5.80 2018-03-14   False
# 1          0.0      0.5  ...           0.0         13.50 2018-02-06   False
# 2          0.0      0.5  ...           0.0          9.35 2018-02-22   False
# 3          0.0      0.5  ...           0.0         26.16 2018-02-08   False
# 4          0.0      0.5  ...           0.0         19.80 2018-03-21   False
# ...        ...      ...  ...           ...           ...        ...     ...
# 7096482    0.0      0.5  ...           0.0         13.56 2018-08-25   False
# 7096483    0.5      0.5  ...           0.0         30.30 2018-07-12   False
# 7096484    0.5      0.5  ...           0.0          7.80 2018-08-10   False
# 7096485    0.5      0.5  ...           0.0          9.20 2018-07-07   False
# 7096486    1.0      0.5  ...           0.0         23.15 2018-09-21   False
#
#          PRCP  SNOW  SNWD       TAVG  Extrem  weekday
# 0        0.01   0.0   0.0   2.222222    True      0.0
# 1        0.00   0.0   0.0  -0.277778   False      0.0
# 2        0.17   0.0   0.0   8.888889    True      0.0
# 3        0.00   0.0   0.0  -1.666667   False      0.0
# 4        0.99   8.2   0.0   1.666667    True      0.0
# ...       ...   ...   ...        ...     ...      ...
# 7096482  0.00   0.0   0.0  23.333333   False      1.0
# 7096483  0.71   0.0   0.0  23.333333    True      0.0
# 7096484  0.00   0.0   0.0  26.111111   False      0.0
# 7096485  0.00   0.0   0.0  21.111111   False      1.0
# 7096486  0.00   0.0   0.0  20.833333   False      0.0
#
# [7096487 rows x 21 columns]

# %%
pip install geopandas
# Out:
# Collecting geopandas
#   Downloading geopandas-0.9.0-py2.py3-none-any.whl (994 kB)
#      |████████████████████████████████| 994 kB 355 kB/s eta 0:00:01
# Collecting shapely>=1.6
#   Downloading Shapely-1.7.1-cp38-cp38-macosx_10_9_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 6.6 MB/s eta 0:00:01
# Collecting fiona>=1.8
#   Downloading Fiona-1.8.20-cp38-cp38-macosx_10_9_x86_64.whl (19.3 MB)
#      |████████████████████████████████| 19.3 MB 549 kB/s  eta 0:00:01
# Collecting pyproj>=2.2.0
#   Downloading pyproj-3.1.0-cp38-cp38-macosx_10_9_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 8.1 MB/s eta 0:00:01     |██████████████████████▋         | 5.4 MB 8.1 MB/s eta 0:00:01
# Requirement already satisfied: pandas>=0.24.0 in /Users/miayokka0926/opt/anaconda3/lib/python3.8/site-packages (from geopandas) (1.2.4)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Collecting click-plugins>=1.0
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: setuptools in /Users/miayokka0926/opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (52.0.0.post20210125)
# Requirement already satisfied: six>=1.7 in /Users/miayokka0926/opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (1.15.0)
# Requirement already satisfied: certifi in /Users/miayokka0926/opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (2020.12.5)
# Collecting munch
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: click>=4.0 in /Users/miayokka0926/opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (7.1.2)
# Requirement already satisfied: attrs>=17 in /Users/miayokka0926/opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (20.3.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/miayokka0926/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.24.0->geopandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/miayokka0926/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.24.0->geopandas) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in /Users/miayokka0926/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.24.0->geopandas) (1.20.1)
# Installing collected packages: munch, cligj, click-plugins, shapely, pyproj, fiona, geopandas
# Successfully installed click-plugins-1.1.1 cligj-0.7.2 fiona-1.8.20 geopandas-0.9.0 munch-2.5.0 pyproj-3.1.0 shapely-1.7.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.12.1-py2.py3-none-any.whl (94 kB)
#      |████████████████████████████████| 94 kB 366 kB/s eta 0:00:01
# Requirement already satisfied: requests in /Users/miayokka0926/opt/anaconda3/lib/python3.8/site-packages (from folium) (2.25.1)
# Requirement already satisfied: numpy in /Users/miayokka0926/opt/anaconda3/lib/python3.8/site-packages (from folium) (1.20.1)
# Requirement already satisfied: jinja2>=2.9 in /Users/miayokka0926/opt/anaconda3/lib/python3.8/site-packages (from folium) (2.11.3)
# Collecting branca>=0.3.0
#   Downloading branca-0.4.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/miayokka0926/opt/anaconda3/lib/python3.8/site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/miayokka0926/opt/anaconda3/lib/python3.8/site-packages (from requests->folium) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/miayokka0926/opt/anaconda3/lib/python3.8/site-packages (from requests->folium) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /Users/miayokka0926/opt/anaconda3/lib/python3.8/site-packages (from requests->folium) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/miayokka0926/opt/anaconda3/lib/python3.8/site-packages (from requests->folium) (1.26.4)
# Installing collected packages: branca, folium
# Successfully installed branca-0.4.2 folium-0.12.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyarrow
# Out:
# Collecting pyarrow
#   Downloading pyarrow-5.0.0-cp38-cp38-macosx_10_13_x86_64.whl (17.6 MB)
#      |████████████████████████████████| 17.6 MB 10.1 MB/s eta 0:00:01    |██████████████████▏             | 10.0 MB 10.1 MB/s eta 0:00:01     |███████████████████▏            | 10.5 MB 10.1 MB/s eta 0:00:01     |██████████████████████▏         | 12.1 MB 10.1 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.16.6 in /Users/miayokka0926/opt/anaconda3/lib/python3.8/site-packages (from pyarrow) (1.20.1)
# Installing collected packages: pyarrow
# Successfully installed pyarrow-5.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
data = {'date':tips_sample['date'],
        'passenger_count': tips_sample['passenger_count'],
        'trip_distance':tips_sample['trip_distance'],
        'fare_amount':tips_sample['fare_amount'],
        'tip_amount': tips_sample['tip_amount'],
        'tolls_amount': tips_sample['tolls_amount'],
        'total_amount': tips_sample['total_amount'],
        'PUloc':tips_sample['PULocationID'],
        'DOloc':tips_sample['DOLocationID']}

tips_sample = pd.DataFrame(data)
tips_sample
# Out:
#               date  passenger_count  trip_distance  fare_amount  tip_amount  \
# 0       2018-03-14                2           0.70          4.5        0.00
# 1       2018-02-06                1           1.97         10.0        2.70
# 2       2018-02-22                1           1.10          7.0        1.55
# 3       2018-02-08                4           5.54         21.0        4.36
# 4       2018-03-21                1           6.00         18.0        1.00
# ...            ...              ...            ...          ...         ...
# 7096482 2018-08-25                1           2.23         10.5        2.26
# 7096483 2018-07-12                1           7.60         27.0        2.00
# 7096484 2018-08-10                2           1.10          6.5        0.00
# 7096485 2018-07-07                1           1.20          6.5        1.40
# 7096486 2018-09-21                1           3.20         17.5        3.85
#
#          tolls_amount  total_amount  PUloc  DOloc
# 0                 0.0          5.80    164    170
# 1                 0.0         13.50    239    236
# 2                 0.0          9.35    237    262
# 3                 0.0         26.16    170    261
# 4                 0.0         19.80    137    168
# ...               ...           ...    ...    ...
# 7096482           0.0         13.56    168    263
# 7096483           0.0         30.30    114     74
# 7096484           0.0          7.80    100    164
# 7096485           0.0          9.20    162    107
# 7096486           0.0         23.15    263    137
#
# [7096487 rows x 9 columns]

# %% [markdown]
# # factors that affect tip amount investigation

# %%
corr = np.corrcoef(tips_sample['trip_distance'], tips_sample['tip_amount'])
print(corr)

pp = sns.pairplot(data=tips_sample,
                  y_vars=['tip_amount'],
                  x_vars=['trip_distance', 'passenger_count', 'fare_amount', 'total_amount'])
# Out:
# [[1.         0.46777784]
#  [0.46777784 1.        ]]

# %% [markdown]
# # tip count by region

# %%
loc_tip_s1 = tips_sample.groupby('PUloc')['tip_amount'].agg('sum')
loc_tip_s1 = pd.DataFrame(loc_tip_s1, index = loc_tip_s1.index)
loc_tip_s1['count'] = tips_sample['PUloc'].value_counts().sort_index()
loc_tip_s1['avg'] = loc_tip_s1['tip_amount'] / loc_tip_s1['count']
loc_tip_s1
# Out:
#        tip_amount   count       avg
# PUloc
# 1           18.07       8  2.258750
# 3           14.85      44  0.337500
# 4        22701.54   15728  1.443384
# 5            1.86       1  1.860000
# 6            3.15       5  0.630000
# ...           ...     ...       ...
# 261      76152.29   41835  1.820301
# 262     118844.96   84890  1.399988
# 263     185359.01  137214  1.350875
# 264     147909.92   98301  1.504663
# 265        650.17     544  1.195165
#
# [255 rows x 3 columns]

# %%
import geopandas as gpd
sf = gpd.read_file("/Users/miayokka0926/Desktop/MAST30034_Python/data/taxi_zones/taxi_zones.shp")
sf['geometry'] = sf['geometry'].to_crs("+proj=longlat +ellps=WGS84 +datum=WGS84 +no_defs")
sf
# Out:
#      OBJECTID  Shape_Leng  Shape_Area                     zone  LocationID  \
# 0           1    0.116357    0.000782           Newark Airport           1
# 1           2    0.433470    0.004866              Jamaica Bay           2
# 2           3    0.084341    0.000314  Allerton/Pelham Gardens           3
# 3           4    0.043567    0.000112            Alphabet City           4
# 4           5    0.092146    0.000498            Arden Heights           5
# ..        ...         ...         ...                      ...         ...
# 258       259    0.126750    0.000395       Woodlawn/Wakefield         259
# 259       260    0.133514    0.000422                 Woodside         260
# 260       261    0.027120    0.000034       World Trade Center         261
# 261       262    0.049064    0.000122           Yorkville East         262
# 262       263    0.037017    0.000066           Yorkville West         263
#
#            borough                                           geometry
# 0              EWR  POLYGON ((-74.18445 40.69500, -74.18449 40.695...
# 1           Queens  MULTIPOLYGON (((-73.82338 40.63899, -73.82277 ...
# 2            Bronx  POLYGON ((-73.84793 40.87134, -73.84725 40.870...
# 3        Manhattan  POLYGON ((-73.97177 40.72582, -73.97179 40.725...
# 4    Staten Island  POLYGON ((-74.17422 40.56257, -74.17349 40.562...
# ..             ...                                                ...
# 258          Bronx  POLYGON ((-73.85107 40.91037, -73.85207 40.909...
# 259         Queens  POLYGON ((-73.90175 40.76078, -73.90147 40.759...
# 260      Manhattan  POLYGON ((-74.01333 40.70503, -74.01327 40.704...
# 261      Manhattan  MULTIPOLYGON (((-73.94383 40.78286, -73.94376 ...
# 262      Manhattan  POLYGON ((-73.95219 40.77302, -73.95269 40.772...
#
# [263 rows x 7 columns]

# %%
gdf_loc_tip_s1 = gpd.GeoDataFrame(pd.merge(loc_tip_s1, sf, left_on=loc_tip_s1.index, right_on='LocationID')).drop('LocationID',axis=1)
gdf_loc_tip_s1
# Out:
#      tip_amount   count       avg  OBJECTID  Shape_Leng  Shape_Area  \
# 0         18.07       8  2.258750         1    0.116357    0.000782
# 1         14.85      44  0.337500         3    0.084341    0.000314
# 2      22701.54   15728  1.443384         4    0.043567    0.000112
# 3          1.86       1  1.860000         5    0.092146    0.000498
# 4          3.15       5  0.630000         6    0.150491    0.000606
# ..          ...     ...       ...       ...         ...         ...
# 247       21.09      62  0.340161       259    0.126750    0.000395
# 248     2838.52    3714  0.764276       260    0.133514    0.000422
# 249    76152.29   41835  1.820301       261    0.027120    0.000034
# 250   118844.96   84890  1.399988       262    0.049064    0.000122
# 251   185359.01  137214  1.350875       263    0.037017    0.000066
#
#                         zone        borough  \
# 0             Newark Airport            EWR
# 1    Allerton/Pelham Gardens          Bronx
# 2              Alphabet City      Manhattan
# 3              Arden Heights  Staten Island
# 4    Arrochar/Fort Wadsworth  Staten Island
# ..                       ...            ...
# 247       Woodlawn/Wakefield          Bronx
# 248                 Woodside         Queens
# 249       World Trade Center      Manhattan
# 250           Yorkville East      Manhattan
# 251           Yorkville West      Manhattan
#
#                                               geometry
# 0    POLYGON ((-74.18445 40.69500, -74.18449 40.695...
# 1    POLYGON ((-73.84793 40.87134, -73.84725 40.870...
# 2    POLYGON ((-73.97177 40.72582, -73.97179 40.725...
# 3    POLYGON ((-74.17422 40.56257, -74.17349 40.562...
# 4    POLYGON ((-74.06367 40.60220, -74.06351 40.602...
# ..                                                 ...
# 247  POLYGON ((-73.85107 40.91037, -73.85207 40.909...
# 248  POLYGON ((-73.90175 40.76078, -73.90147 40.759...
# 249  POLYGON ((-74.01333 40.70503, -74.01327 40.704...
# 250  MULTIPOLYGON (((-73.94383 40.78286, -73.94376 ...
# 251  POLYGON ((-73.95219 40.77302, -73.95269 40.772...
#
# [252 rows x 9 columns]

# %%
y_var = "avg"
vmin, vmax = 0, gdf_loc_tip_s1['avg'].max()
fig, ax = plt.subplots(1, figsize=(11,11))

#title and annotation
ax.set_title('average tips per trip of each region', fontsize=25)

#colorbar legend
sn = plt.cm.ScalarMappable(cmap = 'Blues', norm = plt.Normalize(vmin=vmin, vmax = vmax))

sn.set_array([])
fig.colorbar(sn)

gdf_loc_tip_s1.plot(column = y_var, cmap="Blues", linewidth=1.5,ax=ax,edgecolor = '0.4')
plt.savefig("../plots/average tips per trip of each region.png")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
y_var = "count"
vmin, vmax = 0, gdf_loc_tip_s1['count'].max()
fig, ax = plt.subplots(1, figsize=(11,11))

#title and annotation
ax.set_title('demand of each region', fontsize=25)

#colorbar legend
sn = plt.cm.ScalarMappable(cmap = 'Blues', norm = plt.Normalize(vmin=vmin, vmax = vmax))

sn.set_array([])
fig.colorbar(sn)

gdf_loc_tip_s1.plot(column = y_var, cmap="Blues", linewidth=1.5,ax=ax,edgecolor = '0.4')
plt.savefig("../plots/demand of each region.png")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
